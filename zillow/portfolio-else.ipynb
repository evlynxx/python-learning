# %%
import pandas as pd
import numpy as np

# %%
path = 'sale-median-list-price.csv'
df = pd.read_csv(path)
df
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  2017-12-31  \
# 0      102001         0    United States    country       NaN    257933.0
# 1      394913         1     New York, NY        msa        NY    489300.0
# 2      753899         2  Los Angeles, CA        msa        CA    703332.0
# 3      394463         3      Chicago, IL        msa        IL    274933.0
# 4      394514         4       Dallas, TX        msa        TX    316333.0
# ..        ...       ...              ...        ...       ...         ...
# 891    753929       923       Zapata, TX        msa        TX         NaN
# 892    394743       924    Ketchikan, AK        msa        AK    286500.0
# 893    753874       925        Craig, CO        msa        CO    194967.0
# 894    394767       926       Lamesa, TX        msa        TX    104467.0
# 895    395188       927       Vernon, TX        msa        TX         NaN
#
#      2018-01-31  2018-02-28  2018-03-31  2018-04-30  ...  2021-11-30  \
# ...

# %%
path2 = 'sale-median-sale-price.csv'
df = pd.read_csv(path2)
df
# Out:
#      RegionID  SizeRank             RegionName RegionType StateName  \
# 0      102001         0          United States    country       NaN
# 1      394913         1           New York, NY        msa        NY
# 2      753899         2        Los Angeles, CA        msa        CA
# 3      394463         3            Chicago, IL        msa        IL
# 4      394514         4             Dallas, TX        msa        TX
# ..        ...       ...                    ...        ...       ...
# 632    753909       845             Ottawa, KS        msa        KS
# 633    753921       848  Steamboat Springs, CO        msa        CO
# 634    395004       853         Prineville, OR        msa        OR
# 635    394564       882           Elk City, OK        msa        OK
# 636    394403       889             Borger, TX        msa        TX
#
#      2018-08-31  2018-09-30  2018-10-31  2018-11-30  2018-12-31  ...  \
# 0      234938.0    234364.0    234496.0    236015.0    236405.0  ...
# ...

# %%
path3 = 'sale-median-sale-to-list-ratio.csv'
df = pd.read_csv(path3)
df
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  2018-03-31  \
# 0      102001         0    United States    country       NaN    0.985431
# 1      394913         1     New York, NY        msa        NY    0.977104
# 2      753899         2  Los Angeles, CA        msa        CA    0.999097
# 3      394463         3      Chicago, IL        msa        IL    0.973550
# 4      394514         4       Dallas, TX        msa        TX    0.990678
# ..        ...       ...              ...        ...       ...         ...
# 551    394758       838    La Grande, OR        msa        OR         NaN
# 552    753909       845       Ottawa, KS        msa        KS         NaN
# 553    395004       853   Prineville, OR        msa        OR         NaN
# 554    394564       882     Elk City, OK        msa        OK         NaN
# 555    394403       889       Borger, TX        msa        TX         NaN
#
#      2018-04-30  2018-05-31  2018-06-30  2018-07-31  ...  2021-10-31  \
# ...

# %%
path4 = 'sale-sold-above-list.csv' # %
df = pd.read_csv(path4)
df
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  2018-03-31  \
# 0      102001         0    United States    country       NaN    0.220553
# 1      394913         1     New York, NY        msa        NY    0.190939
# 2      753899         2  Los Angeles, CA        msa        CA    0.388930
# 3      394463         3      Chicago, IL        msa        IL    0.140049
# 4      394514         4       Dallas, TX        msa        TX    0.252622
# ..        ...       ...              ...        ...       ...         ...
# 551    394758       838    La Grande, OR        msa        OR         NaN
# 552    753909       845       Ottawa, KS        msa        KS         NaN
# 553    395004       853   Prineville, OR        msa        OR         NaN
# 554    394564       882     Elk City, OK        msa        OK         NaN
# 555    394403       889       Borger, TX        msa        TX         NaN
#
#      2018-04-30  2018-05-31  2018-06-30  2018-07-31  ...  2021-10-31  \
# ...
