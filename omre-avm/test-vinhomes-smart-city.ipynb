# %%
import pandas as pd
import numpy as np

# %%
path = "Vinhomes Smart City - 18032022.csv"
df1 = pd.read_csv(path)
df1.head()
# Out:
#                  Dự án  Tòa Phân khu   Mã căn  Tầng Loại căn hộ  \
# 0  Vinhomes Smart City  SA2   Sakura  SA20211     2      Studio
# 1  Vinhomes Smart City  SA2   Sakura  SA20503     5         1PN
# 2  Vinhomes Smart City  SA2   Sakura  SA20504     5         3PN
# 3  Vinhomes Smart City  SA2   Sakura  SA20510     5         3PN
# 4  Vinhomes Smart City  SA2   Sakura  SA20511     5      Studio
#
#           Hướng ban công  Diện tích thông thủy  Diện tích tim tường  \
# 0   South West - Tây Nam                  31.5                 34.8
# 1  North East - Đông Bắc                  34.1                 37.5
# 2     Đông Bắc- Đông Nam                  81.7                 90.5
# 3       Tây Bắc- Tây Nam                  77.6                 87.7
# 4   South West - Tây Nam                  31.5                 34.8
#
#   Đơn giá thông thủy  ... Giá gồm VAT và KPBT Đơn giá gồm CSBH CK TTTTD (7%)  \
# 0         46,970,130  ...       1,654,608,306       46,970,130   103,569,136
# ...

# %%
path = 'Vinhomes Smart City - 24062022.csv'
df2 = pd.read_csv(path)
df2.head()
# Out:
#                  Dự án Phân khu  Toà   Mã căn Loại căn hộ     Hướng ban công  \
# 0  Vinhomes Smart City   Sakura  SA2  SA23810         3PN   Tây Bắc- Tây Nam
# 1  Vinhomes Smart City   Sakura  SA2  SA23805         3PN  Đông Nam- Tây Nam
# 2  Vinhomes Smart City   Sakura  SA2  SA23710         3PN   Tây Bắc- Tây Nam
# 3  Vinhomes Smart City   Sakura  SA2  SA23705         3PN  Đông Nam- Tây Nam
# 4  Vinhomes Smart City   Sakura  SA2  SA23610         3PN   Tây Bắc- Tây Nam
#
#    Diện tích thông thủy  Diện tích tim tường Giá chưa VAT và KPBT  \
# 0                  78.3                  NaN        3,743,636,136
# 1                  75.5                  NaN        3,541,123,520
# 2                  78.3                  NaN        3,777,591,062
# 3                  75.5                  NaN        3,572,755,520
# 4                  78.3                  NaN        3,811,546,156
#
#   Giá gồm VAT và KPBT  ... Đơn giá gồm CSBH (exc VAT, KPBT)  CK TTTTD (7%)  \
# ...

# %%
for i,v in enumerate(df1.columns):
    print(i,v)
# Out:
# 0 Dự án
# 1 Tòa
# 2 Phân khu
# 3 Mã căn
# 4 Tầng
# 5 Loại căn hộ
# 6 Hướng ban công
# 7 Diện tích thông thủy
# 8 Diện tích tim tường
# 9 Đơn giá thông thủy
# 10 Giá chưa VAT và KPBT
# 11 Giá gồm VAT và KPBT
# 12 Đơn giá gồm CSBH
# 13 CK TTTTD (7%)
# 14 Đơn giá gồm CSBH (ex VAT, KPBT, CK TTTTĐ)
# 15 Miễn 5 năm DV
# 16 Nội thất
# 17 CK BLNH (0.8%)
# 18 Giá NET
# 19 Đơn giá NET
# 20 Tổng quà tặng

# %%
for i,v in enumerate(df2.columns):
    print(i,v)
# Out:
# 0 Dự án
# 1 Phân khu
# 2 Toà
# 3 Mã căn
# 4 Loại căn hộ
# 5 Hướng ban công
# 6 Diện tích thông thủy
# 7 Diện tích tim tường
# 8 Giá chưa VAT và KPBT
# 9 Giá gồm VAT và KPBT
# 10 Ngày Nhập Quỹ
# 11 Đơn giá gồm CSBH (exc VAT, KPBT)
# 12 CK TTTTD (7%)
# 13 Đơn giá gồm CSBH (ex VAT, KPBT, CK TTTTĐ)
# 14 Miễn 5 năm DV
# 15 Quà tặng chào hè
# 16 Nội thất
# 17 CK BLNH (0.8%)
# 18 Giá NET
# 19 Đơn giá NET
# 20 Tổng quà tặng

# %%
# thử union 2 dataframes

df_test = pd.concat([df1,df2])
df_test.head()
# Out:
#                  Dự án  Tòa Phân khu   Mã căn  Tầng Loại căn hộ  \
# 0  Vinhomes Smart City  SA2   Sakura  SA20211   2.0      Studio
# 1  Vinhomes Smart City  SA2   Sakura  SA20503   5.0         1PN
# 2  Vinhomes Smart City  SA2   Sakura  SA20504   5.0         3PN
# 3  Vinhomes Smart City  SA2   Sakura  SA20510   5.0         3PN
# 4  Vinhomes Smart City  SA2   Sakura  SA20511   5.0      Studio
#
#           Hướng ban công  Diện tích thông thủy  Diện tích tim tường  \
# 0   South West - Tây Nam                  31.5                 34.8
# 1  North East - Đông Bắc                  34.1                 37.5
# 2     Đông Bắc- Đông Nam                  81.7                 90.5
# 3       Tây Bắc- Tây Nam                  77.6                 87.7
# 4   South West - Tây Nam                  31.5                 34.8
#
#   Đơn giá thông thủy  ... Miễn 5 năm DV     Nội thất CK BLNH (0.8%)  \
# 0         46,970,130  ...    22,050,000   70,000,000     11,836,473
# ...

# %%
for i,v in enumerate(df_test.columns):
    print(i,v)
# Out:
# 0 Dự án
# 1 Tòa
# 2 Phân khu
# 3 Mã căn
# 4 Tầng
# 5 Loại căn hộ
# 6 Hướng ban công
# 7 Diện tích thông thủy
# 8 Diện tích tim tường
# 9 Đơn giá thông thủy
# 10 Giá chưa VAT và KPBT
# 11 Giá gồm VAT và KPBT
# 12 Đơn giá gồm CSBH
# 13 CK TTTTD (7%)
# 14 Đơn giá gồm CSBH (ex VAT, KPBT, CK TTTTĐ)
# 15 Miễn 5 năm DV
# 16 Nội thất
# 17 CK BLNH (0.8%)
# 18 Giá NET
# 19 Đơn giá NET
# 20 Tổng quà tặng
# 21 Toà
# 22 Ngày Nhập Quỹ
# 23 Đơn giá gồm CSBH (exc VAT, KPBT)
# 24 Quà tặng chào hè

# %%
list(df_test.columns)
# Out:
# ['Dự án',
#  'Tòa',
#  'Phân khu',
#  'Mã căn',
#  'Tầng',
#  'Loại căn hộ',
#  'Hướng ban công',
#  'Diện tích thông thủy',
#  'Diện tích tim tường',
#  'Đơn giá thông thủy',
#  'Giá chưa VAT và KPBT',
#  'Giá gồm VAT và KPBT',
#  'Đơn giá gồm CSBH',
#  'CK TTTTD (7%)',
#  'Đơn giá gồm CSBH (ex VAT, KPBT, CK TTTTĐ)',
#  'Miễn 5 năm DV',
#  'Nội thất',
#  'CK BLNH (0.8%)',
#  'Giá NET',
#  'Đơn giá NET',
#  'Tổng quà tặng',
#  'Toà',
#  'Ngày Nhập Quỹ',
#  'Đơn giá gồm CSBH (exc VAT, KPBT)',
#  'Quà tặng chào hè']

# %%
# Dưới là những cột cần lấy sau khi union -> có cách nào nhanh hơn thay vì gõ tay k?
col_labels = ['Ngày cập nhật', 'Dự án', 'Tòa', 'Phân khu', 'Mã căn', 'Tầng', 'Khoảng tầng', 'Loại căn hộ', 'Hướng ban công', 'Diện tích thông thủy', 'Diện tích tim tường', 'Giá chưa VAT và KPBT', 'Giá gồm VAT và KPBT', 'Đơn giá gồm CSBH (exc VAT, KPBT, CK TTTTĐ)', 'Tổng quà tặng', 'Giá NET', 'Đơn giá NET']
col1 = ['Dự án', 'Tòa', 'Phân khu', 'Mã căn', 'Tầng', 'Loại căn hộ', 'Hướng ban công', 'Diện tích thông thủy', 'Diện tích tim tường', 'Giá chưa VAT và KPBT', 'Giá gồm VAT và KPBT', 'Tổng quà tặng', 'Giá NET', 'Đơn giá NET']
col2 = ['Dự án', 'Phân khu', 'Mã căn', 'Loại căn hộ', 'Hướng ban công', 'Diện tích thông thủy', 'Diện tích tim tường', 'Giá chưa VAT và KPBT', 'Giá gồm VAT và KPBT', 'Tổng quà tặng', 'Giá NET', 'Đơn giá NET']

# %%
print(len(col1))
print(len(col2))
# Out:
# 14
# 12

# %%
# lấy ra trong df1 những cột thuộc list col1
df1 = df1[col1]
df1.head()
# Out:
#                  Dự án  Tòa Phân khu   Mã căn  Tầng Loại căn hộ  \
# 0  Vinhomes Smart City  SA2   Sakura  SA20211     2      Studio
# 1  Vinhomes Smart City  SA2   Sakura  SA20503     5         1PN
# 2  Vinhomes Smart City  SA2   Sakura  SA20504     5         3PN
# 3  Vinhomes Smart City  SA2   Sakura  SA20510     5         3PN
# 4  Vinhomes Smart City  SA2   Sakura  SA20511     5      Studio
#
#           Hướng ban công  Diện tích thông thủy  Diện tích tim tường  \
# 0   South West - Tây Nam                  31.5                 34.8
# 1  North East - Đông Bắc                  34.1                 37.5
# 2     Đông Bắc- Đông Nam                  81.7                 90.5
# 3       Tây Bắc- Tây Nam                  77.6                 87.7
# 4   South West - Tây Nam                  31.5                 34.8
#
#   Giá chưa VAT và KPBT Giá gồm VAT và KPBT Tổng quà tặng        Giá NET  \
# 0        1,479,559,081       1,654,608,306   207,455,608  1,272,103,473
# ...

# %%
# lấy ra trong df2 những cột thuộc list col2
df2 = df2[col2]
df2.head()
# Out:
#                  Dự án Phân khu   Mã căn Loại căn hộ     Hướng ban công  \
# 0  Vinhomes Smart City   Sakura  SA23810         3PN   Tây Bắc- Tây Nam
# 1  Vinhomes Smart City   Sakura  SA23805         3PN  Đông Nam- Tây Nam
# 2  Vinhomes Smart City   Sakura  SA23710         3PN   Tây Bắc- Tây Nam
# 3  Vinhomes Smart City   Sakura  SA23705         3PN  Đông Nam- Tây Nam
# 4  Vinhomes Smart City   Sakura  SA23610         3PN   Tây Bắc- Tây Nam
#
#    Diện tích thông thủy  Diện tích tim tường Giá chưa VAT và KPBT  \
# 0                  78.3                  NaN        3,743,636,136
# 1                  75.5                  NaN        3,541,123,520
# 2                  78.3                  NaN        3,777,591,062
# 3                  75.5                  NaN        3,572,755,520
# 4                  78.3                  NaN        3,811,546,156
#
#   Giá gồm VAT và KPBT Tổng quà tặng        Giá NET Đơn giá NET
# 0       4,186,663,494   238,303,308  3,273,278,297  41,804,321
# ...

# %%
# union 2 dataframes sau khi đã lọc cột
df_test = pd.concat([df1,df2])
df_test
# Out:
#                   Dự án  Tòa Phân khu   Mã căn  Tầng Loại căn hộ  \
# 0   Vinhomes Smart City  SA2   Sakura  SA20211   2.0      Studio
# 1   Vinhomes Smart City  SA2   Sakura  SA20503   5.0         1PN
# 2   Vinhomes Smart City  SA2   Sakura  SA20504   5.0         3PN
# 3   Vinhomes Smart City  SA2   Sakura  SA20510   5.0         3PN
# 4   Vinhomes Smart City  SA2   Sakura  SA20511   5.0      Studio
# ..                  ...  ...      ...      ...   ...         ...
# 80  Vinhomes Smart City  NaN   Sakura  SA23112   NaN     1PN + 1
# 81  Vinhomes Smart City  NaN   Sakura  SA23210   NaN         3PN
# 82  Vinhomes Smart City  NaN   Sakura  SA23304   NaN         3PN
# 83  Vinhomes Smart City  NaN   Sakura  SA23414   NaN         3PN
# 84  Vinhomes Smart City  NaN   Sakura  SA23814   NaN         3PN
#
#            Hướng ban công  Diện tích thông thủy  Diện tích tim tường  \
# 0    South West - Tây Nam                  31.5                 34.8
# ...

# %%
for i,v in enumerate(df_test.columns):
    print(i,v)
# Out:
# 0 Dự án
# 1 Tòa
# 2 Phân khu
# 3 Mã căn
# 4 Tầng
# 5 Loại căn hộ
# 6 Hướng ban công
# 7 Diện tích thông thủy
# 8 Diện tích tim tường
# 9 Giá chưa VAT và KPBT
# 10 Giá gồm VAT và KPBT
# 11 Tổng quà tặng
# 12 Giá NET
# 13 Đơn giá NET

# %%
df_test.to_csv('union.csv', encoding='utf-8')

# %%
# download data into a xlsx file
df_test.to_excel('union-test.xlsx', sheet_name='vinhomes-smart-city-union', encoding='utf-8', index=False)

'''
- sheet_name: tên của tab
- encoding: để k bị lỗi vietkey
- index=False: khi mở file xlsx dưới lap thì sẽ tự động bỏ cột index đi
'''
# Out:
# '\n- sheet_name: tên của tab\n- encoding: để k bị lỗi vietkey\n- index=False: khi mở file xlsx dưới lap thì sẽ tự động bỏ cột index đi\n'

# %%
# khi union 2 df lại với nhau -> index đang bị lẫn của cả 2 df -> reset lại index
df_test.reset_index(drop=True, inplace=True)
df_test
# Out:
#                    Dự án  Tòa Phân khu   Mã căn  Tầng Loại căn hộ  \
# 0    Vinhomes Smart City  SA2   Sakura  SA20211   2.0      Studio
# 1    Vinhomes Smart City  SA2   Sakura  SA20503   5.0         1PN
# 2    Vinhomes Smart City  SA2   Sakura  SA20504   5.0         3PN
# 3    Vinhomes Smart City  SA2   Sakura  SA20510   5.0         3PN
# 4    Vinhomes Smart City  SA2   Sakura  SA20511   5.0      Studio
# ..                   ...  ...      ...      ...   ...         ...
# 314  Vinhomes Smart City  NaN   Sakura  SA23112   NaN     1PN + 1
# 315  Vinhomes Smart City  NaN   Sakura  SA23210   NaN         3PN
# 316  Vinhomes Smart City  NaN   Sakura  SA23304   NaN         3PN
# 317  Vinhomes Smart City  NaN   Sakura  SA23414   NaN         3PN
# 318  Vinhomes Smart City  NaN   Sakura  SA23814   NaN         3PN
#
#             Hướng ban công  Diện tích thông thủy  Diện tích tim tường  \
# 0     South West - Tây Nam                  31.5                 34.8
# ...

# %%
# tạo ra cột ngày riêng cho 2 df
updated_date_1 = [18032022]
updated_date_2 = [24062022]

x = list(updated_date_1 * len(df1))
y = list(updated_date_2 * len(df2))

# %%
# cách 1: gán giá trị của list x, y vào cột mới (tên đc specified trong '') -> cột mới add vào cuối cùng
df1['Ngày cập nhật'] = x
df2['Ngày cập nhât'] = y

# %%
# cách 2: dùng hàm insert -> có thể assign vị trí của cột mới
df1.insert(0, 'Ngày cập nhật', x, True)

# %%
# lấy số dòng của df
len(df_test)
# Out:
# 319

# %%
df1.head()
# Out:
#    Ngày cập nhật                Dự án  Tòa Phân khu   Mã căn  Tầng  \
# 0       18032022  Vinhomes Smart City  SA2   Sakura  SA20211     2
# 1       18032022  Vinhomes Smart City  SA2   Sakura  SA20503     5
# 2       18032022  Vinhomes Smart City  SA2   Sakura  SA20504     5
# 3       18032022  Vinhomes Smart City  SA2   Sakura  SA20510     5
# 4       18032022  Vinhomes Smart City  SA2   Sakura  SA20511     5
#
#   Loại căn hộ         Hướng ban công  Diện tích thông thủy  \
# 0      Studio   South West - Tây Nam                  31.5
# 1         1PN  North East - Đông Bắc                  34.1
# 2         3PN     Đông Bắc- Đông Nam                  81.7
# 3         3PN       Tây Bắc- Tây Nam                  77.6
# 4      Studio   South West - Tây Nam                  31.5
#
#    Diện tích tim tường Giá chưa VAT và KPBT Giá gồm VAT và KPBT Tổng quà tặng  \
# 0                 34.8        1,479,559,081       1,654,608,306   207,455,608
# ...

# %%
# drop 1 cột
df1.drop('Ngày cập nhật', inplace=True, axis=1)

'''
- inplace=True: diễn ra ngày trong original object
- axis=1: xóa cột chứ kp dòng
'''
# Out:
# '\n- inplace=True: diễn ra ngày trong original object\n- axis=1: xóa cột chứ kp dòng\n'

# %%
df1.head()
# Out:
#                  Dự án  Tòa Phân khu   Mã căn  Tầng Loại căn hộ  \
# 0  Vinhomes Smart City  SA2   Sakura  SA20211     2      Studio
# 1  Vinhomes Smart City  SA2   Sakura  SA20503     5         1PN
# 2  Vinhomes Smart City  SA2   Sakura  SA20504     5         3PN
# 3  Vinhomes Smart City  SA2   Sakura  SA20510     5         3PN
# 4  Vinhomes Smart City  SA2   Sakura  SA20511     5      Studio
#
#           Hướng ban công  Diện tích thông thủy  Diện tích tim tường  \
# 0   South West - Tây Nam                  31.5                 34.8
# 1  North East - Đông Bắc                  34.1                 37.5
# 2     Đông Bắc- Đông Nam                  81.7                 90.5
# 3       Tây Bắc- Tây Nam                  77.6                 87.7
# 4   South West - Tây Nam                  31.5                 34.8
#
#   Giá chưa VAT và KPBT Giá gồm VAT và KPBT Tổng quà tặng        Giá NET  \
# 0        1,479,559,081       1,654,608,306   207,455,608  1,272,103,473
# ...

# %%
df1.insert(0, 'Ngày cập nhật', x, True)
df1.head()
# Out:
#    Ngày cập nhật                Dự án  Tòa Phân khu   Mã căn  Tầng  \
# 0       18032022  Vinhomes Smart City  SA2   Sakura  SA20211     2
# 1       18032022  Vinhomes Smart City  SA2   Sakura  SA20503     5
# 2       18032022  Vinhomes Smart City  SA2   Sakura  SA20504     5
# 3       18032022  Vinhomes Smart City  SA2   Sakura  SA20510     5
# 4       18032022  Vinhomes Smart City  SA2   Sakura  SA20511     5
#
#   Loại căn hộ         Hướng ban công  Diện tích thông thủy  \
# 0      Studio   South West - Tây Nam                  31.5
# 1         1PN  North East - Đông Bắc                  34.1
# 2         3PN     Đông Bắc- Đông Nam                  81.7
# 3         3PN       Tây Bắc- Tây Nam                  77.6
# 4      Studio   South West - Tây Nam                  31.5
#
#    Diện tích tim tường Giá chưa VAT và KPBT Giá gồm VAT và KPBT Tổng quà tặng  \
# 0                 34.8        1,479,559,081       1,654,608,306   207,455,608
# ...

# %%
df1.drop(df1.columns[-1], axis=1, inplace=True)
df1.head()
# Out:
#    Ngày cập nhật                Dự án  Tòa Phân khu   Mã căn  Tầng  \
# 0       18032022  Vinhomes Smart City  SA2   Sakura  SA20211     2
# 1       18032022  Vinhomes Smart City  SA2   Sakura  SA20503     5
# 2       18032022  Vinhomes Smart City  SA2   Sakura  SA20504     5
# 3       18032022  Vinhomes Smart City  SA2   Sakura  SA20510     5
# 4       18032022  Vinhomes Smart City  SA2   Sakura  SA20511     5
#
#   Loại căn hộ         Hướng ban công  Diện tích thông thủy  \
# 0      Studio   South West - Tây Nam                  31.5
# 1         1PN  North East - Đông Bắc                  34.1
# 2         3PN     Đông Bắc- Đông Nam                  81.7
# 3         3PN       Tây Bắc- Tây Nam                  77.6
# 4      Studio   South West - Tây Nam                  31.5
#
#    Diện tích tim tường Giá chưa VAT và KPBT Giá gồm VAT và KPBT Tổng quà tặng  \
# 0                 34.8        1,479,559,081       1,654,608,306   207,455,608
# ...

# %%
df1.head()
# Out:
#    Ngày cập nhật                Dự án  Tòa Phân khu   Mã căn  Tầng  \
# 0       18032022  Vinhomes Smart City  SA2   Sakura  SA20211     2
# 1       18032022  Vinhomes Smart City  SA2   Sakura  SA20503     5
# 2       18032022  Vinhomes Smart City  SA2   Sakura  SA20504     5
# 3       18032022  Vinhomes Smart City  SA2   Sakura  SA20510     5
# 4       18032022  Vinhomes Smart City  SA2   Sakura  SA20511     5
#
#   Loại căn hộ         Hướng ban công  Diện tích thông thủy  \
# 0      Studio   South West - Tây Nam                  31.5
# 1         1PN  North East - Đông Bắc                  34.1
# 2         3PN     Đông Bắc- Đông Nam                  81.7
# 3         3PN       Tây Bắc- Tây Nam                  77.6
# 4      Studio   South West - Tây Nam                  31.5
#
#    Diện tích tim tường Giá chưa VAT và KPBT Giá gồm VAT và KPBT Tổng quà tặng  \
# 0                 34.8        1,479,559,081       1,654,608,306   207,455,608
# ...

# %%
df1.head()
# Out:
#    Ngày cập nhật                Dự án  Tòa Phân khu   Mã căn  Tầng  \
# 0       18032022  Vinhomes Smart City  SA2   Sakura  SA20211     2
# 1       18032022  Vinhomes Smart City  SA2   Sakura  SA20503     5
# 2       18032022  Vinhomes Smart City  SA2   Sakura  SA20504     5
# 3       18032022  Vinhomes Smart City  SA2   Sakura  SA20510     5
# 4       18032022  Vinhomes Smart City  SA2   Sakura  SA20511     5
#
#   Loại căn hộ         Hướng ban công  Diện tích thông thủy  \
# 0      Studio   South West - Tây Nam                  31.5
# 1         1PN  North East - Đông Bắc                  34.1
# 2         3PN     Đông Bắc- Đông Nam                  81.7
# 3         3PN       Tây Bắc- Tây Nam                  77.6
# 4      Studio   South West - Tây Nam                  31.5
#
#    Diện tích tim tường Giá chưa VAT và KPBT Giá gồm VAT và KPBT Tổng quà tặng  \
# 0                 34.8        1,479,559,081       1,654,608,306   207,455,608
# ...

# %%
df1.drop(df1.columns[0], axis=1, inplace=True)

# %%
df1.head()
# Out:
#    Ngày cập nhật                Dự án  Tòa Phân khu   Mã căn  Tầng  \
# 0       18032022  Vinhomes Smart City  SA2   Sakura  SA20211     2
# 1       18032022  Vinhomes Smart City  SA2   Sakura  SA20503     5
# 2       18032022  Vinhomes Smart City  SA2   Sakura  SA20504     5
# 3       18032022  Vinhomes Smart City  SA2   Sakura  SA20510     5
# 4       18032022  Vinhomes Smart City  SA2   Sakura  SA20511     5
#
#   Loại căn hộ         Hướng ban công  Diện tích thông thủy  \
# 0      Studio   South West - Tây Nam                  31.5
# 1         1PN  North East - Đông Bắc                  34.1
# 2         3PN     Đông Bắc- Đông Nam                  81.7
# 3         3PN       Tây Bắc- Tây Nam                  77.6
# 4      Studio   South West - Tây Nam                  31.5
#
#    Diện tích tim tường Giá chưa VAT và KPBT Giá gồm VAT và KPBT Tổng quà tặng  \
# 0                 34.8        1,479,559,081       1,654,608,306   207,455,608
# ...

# %%
for i,v in enumerate(df1.columns):
    print(i,v)
# Out:
# 0 Dự án
# 1 Tòa
# 2 Phân khu
# 3 Mã căn
# 4 Tầng
# 5 Loại căn hộ
# 6 Hướng ban công
# 7 Diện tích thông thủy
# 8 Diện tích tim tường
# 9 Giá chưa VAT và KPBT
# 10 Giá gồm VAT và KPBT
# 11 Tổng quà tặng
# 12 Giá NET
# 13 Đơn giá NET

# %%
df1.insert(0,'Ngày cập nhật',x)
df1.head()
# Out:
#    Ngày cập nhật                Dự án  Tòa Phân khu   Mã căn  Tầng  \
# 0       18032022  Vinhomes Smart City  SA2   Sakura  SA20211     2
# 1       18032022  Vinhomes Smart City  SA2   Sakura  SA20503     5
# 2       18032022  Vinhomes Smart City  SA2   Sakura  SA20504     5
# 3       18032022  Vinhomes Smart City  SA2   Sakura  SA20510     5
# 4       18032022  Vinhomes Smart City  SA2   Sakura  SA20511     5
#
#   Loại căn hộ         Hướng ban công  Diện tích thông thủy  \
# 0      Studio   South West - Tây Nam                  31.5
# 1         1PN  North East - Đông Bắc                  34.1
# 2         3PN     Đông Bắc- Đông Nam                  81.7
# 3         3PN       Tây Bắc- Tây Nam                  77.6
# 4      Studio   South West - Tây Nam                  31.5
#
#    Diện tích tim tường Giá chưa VAT và KPBT Giá gồm VAT và KPBT Tổng quà tặng  \
# 0                 34.8        1,479,559,081       1,654,608,306   207,455,608
# ...

# %%
# chuyển type của cột Ngày cập nhật từ string sang datetime
df1['Ngày cập nhật'] = pd.to_datetime(df1['Ngày cập nhật'], format='%d%m%Y')
df1.head()
# Out:
#   Ngày cập nhật                Dự án  Tòa Phân khu   Mã căn  Tầng Loại căn hộ  \
# 0    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20211     2      Studio
# 1    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20503     5         1PN
# 2    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20504     5         3PN
# 3    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20510     5         3PN
# 4    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20511     5      Studio
#
#           Hướng ban công  Diện tích thông thủy  Diện tích tim tường  \
# 0   South West - Tây Nam                  31.5                 34.8
# 1  North East - Đông Bắc                  34.1                 37.5
# 2     Đông Bắc- Đông Nam                  81.7                 90.5
# 3       Tây Bắc- Tây Nam                  77.6                 87.7
# 4   South West - Tây Nam                  31.5                 34.8
#
#   Giá chưa VAT và KPBT Giá gồm VAT và KPBT Tổng quà tặng        Giá NET
# ...

# %%
df1.columns[0] = pd.to_datetime(df1.columns[0], format='%d%m%Y')
df1.head()

# lỗi: vì df1.columns[0] chỉ trả về tên cột ở index=0 (dạng string)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\chau.luu_onemount\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     455             try:
# --> 456                 values, tz = conversion.datetime_to_datetime64(arg)
#     457                 dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-772bb07907d1> in <module>
# ----> 1 df1.columns[0] = pd.to_datetime(df1.columns[0], format='%d%m%Y')
#       2 df1.head()
#
# ...

# %%
# trả về series gồm tất cả các giá trị ở cột có index=0
df1[df1.columns[0]]
# Out:
# 0     2022-03-18
# 1     2022-03-18
# 2     2022-03-18
# 3     2022-03-18
# 4     2022-03-18
#          ...
# 229   2022-03-18
# 230   2022-03-18
# 231   2022-03-18
# 232   2022-03-18
# 233   2022-03-18
# Name: Ngày cập nhật, Length: 234, dtype: datetime64[ns]

# %%
# cách 2
df1.iloc[:, 0]
# Out:
# 0     2022-03-18
# 1     2022-03-18
# 2     2022-03-18
# 3     2022-03-18
# 4     2022-03-18
#          ...
# 229   2022-03-18
# 230   2022-03-18
# 231   2022-03-18
# 232   2022-03-18
# 233   2022-03-18
# Name: Ngày cập nhật, Length: 234, dtype: datetime64[ns]

# %%
print(col_labels)
# Out:
# ['Ngày cập nhật', 'Dự án', 'Tòa', 'Phân khu', 'Mã căn', 'Tầng', 'Khoảng tầng', 'Loại căn hộ', 'Hướng ban công', 'Diện tích thông thủy', 'Diện tích tim tường', 'Giá chưa VAT và KPBT', 'Giá gồm VAT và KPBT', 'Đơn giá gồm CSBH (exc VAT, KPBT, CK TTTTĐ)', 'Tổng quà tặng', 'Giá NET', 'Đơn giá NET']

# %%
# lấy ra những cột trong df1 mà giao với col_labels (inner join)
test_2 = df1[df1.columns.intersection(col_labels)]
test_2
# Out:
#     Ngày cập nhật                Dự án  Tòa Phân khu   Mã căn  Tầng  \
# 0      2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20211     2
# 1      2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20503     5
# 2      2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20504     5
# 3      2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20510     5
# 4      2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20511     5
# ..            ...                  ...  ...      ...      ...   ...
# 229    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA23811    38
# 230    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA23812    38
# 231    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA23814    38
# 232    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA23817    38
# 233    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA23818    38
#
#     Loại căn hộ         Hướng ban công  Diện tích thông thủy  \
# 0        Studio   South West - Tây Nam                  31.5
# ...

# %%
# cách 2 để lấy ra những cột cần
df1 = df1.filter(col_labels)
df1
# Out:
#     Ngày cập nhật                Dự án  Tòa Phân khu   Mã căn  Tầng  \
# 0      2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20211     2
# 1      2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20503     5
# 2      2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20504     5
# 3      2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20510     5
# 4      2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20511     5
# ..            ...                  ...  ...      ...      ...   ...
# 229    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA23811    38
# 230    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA23812    38
# 231    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA23814    38
# 232    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA23817    38
# 233    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA23818    38
#
#     Loại căn hộ         Hướng ban công  Diện tích thông thủy  \
# 0        Studio   South West - Tây Nam                  31.5
# ...

# %%
type(pd.Series(col_labels))
# Out:
# pandas.core.series.Series

# %%
type(pd.Series(df1.columns))
# Out:
# pandas.core.series.Series

# %%
# lấy ra tên những cột k giao nhau

a = pd.Series(col_labels)
b = pd.Series(df1.columns)
missing_col = a[~a.isin(b)]
missing_col = list(missing_col)

# %%
# tạo df rỗng với tên cột
df_null = pd.DataFrame(columns=missing_col)
df_null
# Out:
# Empty DataFrame
# Columns: [Khoảng tầng, Đơn giá gồm CSBH (exc VAT, KPBT, CK TTTTĐ), Đơn giá NET]
# Index: []

# %%
# thử union 2 dataframes

df_test = pd.concat([df1,df_null])
df_test.head()
# Out:
#   Ngày cập nhật                Dự án  Tòa Phân khu   Mã căn  Tầng Loại căn hộ  \
# 0    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20211   2.0      Studio
# 1    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20503   5.0         1PN
# 2    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20504   5.0         3PN
# 3    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20510   5.0         3PN
# 4    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20511   5.0      Studio
#
#           Hướng ban công  Diện tích thông thủy  Diện tích tim tường  \
# 0   South West - Tây Nam                  31.5                 34.8
# 1  North East - Đông Bắc                  34.1                 37.5
# 2     Đông Bắc- Đông Nam                  81.7                 90.5
# 3       Tây Bắc- Tây Nam                  77.6                 87.7
# 4   South West - Tây Nam                  31.5                 34.8
#
#   Giá chưa VAT và KPBT Giá gồm VAT và KPBT Tổng quà tặng        Giá NET  \
# ...

# %%
# sắp xếp lại vị trí các cột trong df theo thứ tự tên cột trong list col_labels
df_rearrange = df_test.reindex(col_labels, axis=1)
df_rearrange
# Out:
#     Ngày cập nhật                Dự án  Tòa Phân khu   Mã căn  Tầng  \
# 0      2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20211   2.0
# 1      2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20503   5.0
# 2      2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20504   5.0
# 3      2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20510   5.0
# 4      2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20511   5.0
# ..            ...                  ...  ...      ...      ...   ...
# 229    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA23811  38.0
# 230    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA23812  38.0
# 231    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA23814  38.0
# 232    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA23817  38.0
# 233    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA23818  38.0
#
#     Khoảng tầng Loại căn hộ         Hướng ban công  Diện tích thông thủy  \
# 0           NaN      Studio   South West - Tây Nam                  31.5
# ...

# %%
test = df_rearrange
test.head(3)
# Out:
#   Ngày cập nhật                Dự án  Tòa Phân khu   Mã căn  Tầng Khoảng tầng  \
# 0    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20211   2.0         NaN
# 1    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20503   5.0         NaN
# 2    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20504   5.0         NaN
#
#   Loại căn hộ         Hướng ban công  Diện tích thông thủy  \
# 0      Studio   South West - Tây Nam                  31.5
# 1         1PN  North East - Đông Bắc                  34.1
# 2         3PN     Đông Bắc- Đông Nam                  81.7
#
#    Diện tích tim tường Giá chưa VAT và KPBT Giá gồm VAT và KPBT  \
# 0                 34.8        1,479,559,081       1,654,608,306
# 1                 37.5        1,580,121,848       1,767,032,432
# 2                 90.5        3,769,413,064       4,215,264,042
#
#   Đơn giá gồm CSBH (exc VAT, KPBT, CK TTTTĐ) Tổng quà tặng        Giá NET  \
# 0                                        NaN   207,455,608  1,272,103,473
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Ngày cập nhật                               234 non-null    datetime64[ns]
#  1   Dự án                                       234 non-null    object
#  2   Tòa                                         234 non-null    object
#  3   Phân khu                                    234 non-null    object
#  4   Mã căn                                      234 non-null    object
#  5   Tầng                                        234 non-null    float64
#  6   Khoảng tầng                                 0 non-null      object
#  7   Loại căn hộ                                 234 non-null    object
#  8   Hướng ban công                              234 non-null    object
# ...

# %%
test.iloc[:,-2].astype(np.int64)
# Out:
# 0      1272103473
# 1      1363002344
# 2      3298208845
# 3      3479322364
# 4      1314316315
#           ...
# 229    1193838786
# 230    1633854512
# 231    3101478321
# 232    1921220248
# 233    1915075557
# Name: Giá NET, Length: 234, dtype: int64

# %%
for x in range (12,16,1): # cột index=16 là null
    test[test.columns[x]] = test[test.columns[x]].str.replace(',','').astype(float)
    x +=1
test.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-8ac3ee6466ee> in <module>
#       1 for x in range (12,16,1): # cột index=16 là null
# ----> 2     test[test.columns[x]] = test[test.columns[x]].str.replace(',','').astype(float)
#       3     x +=1
#       4 test.info()
#
# c:\Users\chau.luu_onemount\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# c:\Users\chau.luu_onemount\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# ...

# %%
# ilox[row,col]
test.iloc[11].str.replace(',','').astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-7c46adf6a5e6> in <module>
#       1 # ilox[row,col]
# ----> 2 test.iloc[11].str.replace(',','').astype(int)
#
# c:\Users\chau.luu_onemount\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in wrapper(self, *args, **kwargs)
#      99                 )
#     100                 raise TypeError(msg)
# --> 101             return func(self, *args, **kwargs)
#     102
#     103         wrapper.__name__ = func_name
#
# c:\Users\chau.luu_onemount\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in replace(self, pat, repl, n, case, flags, regex)
#    1309                 warnings.warn(msg, FutureWarning, stacklevel=3)
#    1310             regex = True
# -> 1311         result = self._data.array._str_replace(
#    1312             pat, repl, n=n, case=case, flags=flags, regex=regex
# ...

# %%
test.head()
# Out:
#   Ngày cập nhật                Dự án  Tòa Phân khu   Mã căn  Tầng Khoảng tầng  \
# 0    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20211   2.0         NaN
# 1    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20503   5.0         NaN
# 2    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20504   5.0         NaN
# 3    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20510   5.0         NaN
# 4    2022-03-18  Vinhomes Smart City  SA2   Sakura  SA20511   5.0         NaN
#
#   Loại căn hộ         Hướng ban công  Diện tích thông thủy  \
# 0      Studio   South West - Tây Nam                  31.5
# 1         1PN  North East - Đông Bắc                  34.1
# 2         3PN     Đông Bắc- Đông Nam                  81.7
# 3         3PN       Tây Bắc- Tây Nam                  77.6
# 4      Studio   South West - Tây Nam                  31.5
#
#    Diện tích tim tường  Giá chưa VAT và KPBT  Giá gồm VAT và KPBT  \
# 0                 34.8          1.479559e+09         1.654608e+09
# ...

# %%
# df_final.to_excel('union_final.xlsx', sheet_name='vinhomes-smart-city-union', encoding='utf-8', index=False)

table.to_excel('caculation.xlsx', sheet_name='table_calculation', encoding='utf-8')

# %%
# max(giá chưa VAT và KPBT) theo loại căn hộ

calculation = test.groupby('Loại căn hộ').agg({'Giá chưa VAT và KPBT':['max','min'], 'Giá gồm VAT và KPBT':['max','min']})
# calculation = calculation.rename(columns={'Giá chưa VAT và KPBT':'Max Giá chưa bao gồm', 'Giá gồm VAT và KPBT':'Min Giá bao gồm'})
table = pd.DataFrame(calculation)
table
# Out:
#                    Giá chưa VAT và KPBT               Giá gồm VAT và KPBT  \
#                                     max           min                 max
# Loại căn hộ
# 1PN                        1.684868e+09  1.545317e+09        1.884332e+09
# 1PN + 1                    2.132268e+09  1.880569e+09        2.384739e+09
# 2PN                        2.530830e+09  2.248694e+09        2.830200e+09
# 2PN + 1 (2 Toilet)         3.202834e+09  2.919304e+09        3.582155e+09
# 3PN                        4.129081e+09  3.437984e+09        4.618037e+09
# Studio                     1.583118e+09  1.267661e+09        1.770586e+09
#
#
#                              min
# Loại căn hộ
# 1PN                 1.728035e+09
# 1PN + 1             2.102835e+09
# 2PN                 2.514207e+09
# 2PN + 1 (2 Toilet)  3.264601e+09
# 3PN                 3.844555e+09
# Studio              1.417568e+09
